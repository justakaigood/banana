# %% [markdown]
# 自訂義三角函數圖

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
π=np.pi

# %%
a=input()
b=input()
c=input()
x=np.linspace(int(a),int(b),int(c))
y=np.tan(x)
plt.plot(x,y)
# Out:
# 73156
# 3177
# 7869
