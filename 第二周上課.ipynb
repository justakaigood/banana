# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
np.random.randint(1,10,10)
# Out:
# array([1, 9, 9, 2, 4, 2, 1, 4, 2, 8])

# %%
x=np.random.randn(100)

# %%
x.std()
# Out:
# 1.0040221366774975

# %%
plt.plot(x)

# %%
x+37
# Out:
# array([37.45668983, 36.01006826, 36.12062181, 35.99010777, 36.26422274,
#        35.65606816, 37.17322731, 37.56850192, 36.2963983 , 36.18821419,
#        36.56558788, 34.43694845, 36.82710158, 36.23004388, 37.32001041,
#        36.11968208, 37.82534992, 36.40289205, 38.7835673 , 39.08335917,
#        38.44258719, 37.94322344, 35.83640827, 37.39432255, 35.01448106,
#        35.46496317, 36.63774453, 35.36629388, 37.18569905, 37.79466352,
#        35.1478156 , 37.10387426, 37.40768556, 37.17009666, 38.0654282 ,
#        36.31148724, 36.83752707, 37.17050123, 38.09270137, 36.30168088,
#        37.92461577, 37.00470639, 38.53061512, 38.06863697, 36.67848309,
#        38.17885435, 36.68257923, 36.72670643, 37.41304007, 37.06585523,
#        37.16301675, 37.33482558, 36.17201165, 39.13304995, 36.5253079 ,
#        36.95291168, 36.30585169, 36.61239403, 36.24685481, 36.07572734,
#        35.41697741, 37.05366776, 36.84831982, 36.56574088, 37.36065052,
# ...

# %%
x-37
# Out:
# array([-36.54331017, -37.98993174, -37.87937819, -38.00989223,
#        -37.73577726, -38.34393184, -36.82677269, -36.43149808,
#        -37.7036017 , -37.81178581, -37.43441212, -39.56305155,
#        -37.17289842, -37.76995612, -36.67998959, -37.88031792,
#        -36.17465008, -37.59710795, -35.2164327 , -34.91664083,
#        -35.55741281, -36.05677656, -38.16359173, -36.60567745,
#        -38.98551894, -38.53503683, -37.36225547, -38.63370612,
#        -36.81430095, -36.20533648, -38.8521844 , -36.89612574,
#        -36.59231444, -36.82990334, -35.9345718 , -37.68851276,
#        -37.16247293, -36.82949877, -35.90729863, -37.69831912,
#        -36.07538423, -36.99529361, -35.46938488, -35.93136303,
#        -37.32151691, -35.82114565, -37.31742077, -37.27329357,
#        -36.58695993, -36.93414477, -36.83698325, -36.66517442,
#        -37.82798835, -34.86695005, -37.4746921 , -37.04708832,
#        -37.69414831, -37.38760597, -37.75314519, -37.92427266,
# ...

# %%
x=5*x+37

# %%
x
# Out:
# array([233.41724564, 197.25170644, 200.01554513, 196.75269435,
#        203.60556838, 188.40170393, 226.33068264, 236.21254811,
#        204.40995744, 201.70535486, 211.13969688, 157.92371136,
#        217.67753954, 202.75109709, 230.00026023, 199.9920521 ,
#        242.63374812, 207.07230125, 266.58918257, 274.08397927,
#        258.06467976, 245.58058589, 192.91020686, 231.85806382,
#        172.36202659, 183.62407937, 212.94361316, 181.15734704,
#        226.64247631, 241.86658807, 175.69539005, 224.59685646,
#        232.19213904, 226.25241639, 248.63570493, 204.78718094,
#        217.93817669, 226.26253069, 249.31753426, 204.54202191,
#        245.11539422, 222.11765981, 260.265378  , 248.71592436,
#        213.96207727, 251.4713588 , 214.06448065, 215.16766083,
#        232.32600179, 223.64638073, 226.07541874, 230.37063944,
#        201.3002913 , 275.32624887, 210.13269754, 220.8227919 ,
#        204.64629232, 212.30985063, 203.17137018, 198.89318339,
# ...

# %%
x=np.linspace(0,10,200)

# %%
y=np.sin(x)+0.8*x

# %%
plt.plot(x,y)

# %%
y=np.sin(x)+0.8*x+0.4*np.random.randn(200)

# %%
plt.scatter(x,y)

# %% [markdown]
# #1
# ##2
# ###3
#
# AAAAAAAAAAAAAAAAA

# %% [markdown]
# ###分點說明
#
# * python
# * matplotlib

# %% [markdown]
# ###有順序的分項
# 1.python
# 2.numpy

# %% [markdown]
# ### 做超連結
#
# AAAAAAAAAAAAAAAA
# (https://www.youtube.com/?gl=TW&tab=r1)

# %% [markdown]
# ![aaa](p8377191a546510502.jpg)

# %%
### 支援 LaTeX

我現在有一個函數 $f(x)=x^3-x^2+5$

$$L=\int_a^b x^3-2x^2+5\, dx$$
# Out:
#   File "<ipython-input-25-2a7d2e4e268a>", line 3
#     我現在有一個函數 $f(x)=x^3-x^2+5$
#              ^
# SyntaxError: invalid syntax

# %%
a=3
b=7

# %%
a+b
# Out:
# 10

# %%
spam = "this is a book"

# %%
spam
# Out:
# 'this is a book'

# %%
L=["a","b","c"]

# %%
list("abcdefg")
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f', 'g']

# %%
range(0,10)
# Out:
# range(0, 10)

# %%
L1=list("123456")
L2=list("234567")

# %%
L1*2
# Out:
# ['1', '2', '3', '4', '5', '6', '1', '2', '3', '4', '5', '6']

# %%
a={"apple":"banana"}

# %%
a["apple"]
# Out:
# 'banana'

# %%
L1
# Out:
# ['1', '2', '3', '4', '5', '6']

# %%
L1[2]
# Out:
# '3'

# %%
L1[1:]
# Out:
# ['2', '3', '4', '5', '6']

# %%
ham= input("aaaaaaaa")
# Out:
# aaaaaaaa111

# %%
ham=input("AAAAAAAAAAAAAAAAAA")
print("AAAAAAAAAAAA:BBBBB")

# %%
ham

# %%
def pipi():
    ham=imput("aaaaaaa")
    print("aaaa:bbbb")

# %%
pipi()

# %%
def cube(x):
    print(x**3)

# %%
a=cube(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-a3f1c0052a2c> in <module>
# ----> 1 a=cube(3)
#
# NameError: name 'cube' is not defined

# %%
def g(x):
    print(x)

# %%
from ipywidgets import interact

# %%
interact(g,x=3)
# Out:
# interactive(children=(IntSlider(value=3, description='x', max=9, min=-3), Output()), _dom_classes=('widget-int…
# <function __main__.g(x)>

# %%
interact(g,x="hi")
# Out:
# interactive(children=(Text(value='hi', description='x'), Output()), _dom_classes=('widget-interact',))
# <function __main__.g(x)>

# %%
def pipi2(x):
    print("ppp")

# %%
interact(pipi2,x="")
# Out:
# interactive(children=(Text(value='', description='x'), Output()), _dom_classes=('widget-interact',))
# <function __main__.pipi2(x)>

# %%
from ipywidgets import interact_manual

# %%
interact_manual(pipi2,x="")
# Out:
# interactive(children=(Text(value='', description='x'), Button(description='Run Interact', style=ButtonStyle())…
# <function __main__.pipi2(x)>

# %%
def move(n):
    print("*n+(aaaaaaa)")

# %%
move(10)
# Out:
# *n+(aaaaaaa)

# %%
interact(move,n=(1,40))
# Out:
# interactive(children=(IntSlider(value=20, description='n', max=40, min=1), Output()), _dom_classes=('widget-in…
# <function __main__.move(n)>

# %%
def myplot(n=1):
    x=np.linspace(-5,5,100)
    y=np.sin(n*x)

# %%
plt.plot(x,y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-d8b592bf313e> in <module>
# ----> 1 plt.plot(x,y)
#
# NameError: name 'plt' is not defined

# %%
g=input("tt")
g=float(g)
if g>60:
    print("aaaaa")

# %%
msg=input(">")
if("a" in msg):
    print("b")
else:
    print("c")

# %%
msg = ""

while (msg 1= "bye"):
    msg = input(">>")
    print("pp")
