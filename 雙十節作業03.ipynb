# %% [markdown]
# 鉛筆

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd 
import random

# %%
for n in range(1,20):
    print(" "*(20-n),"@"*2*n," "*(20-n))
for r in range(1,80):
    print("@"*10," "*5,"@"*10," "*5,"@"*10)
for m in range(1,14):
    print("="*44)
# Out:
#                     @@
#                    @@@@
#                   @@@@@@
#                  @@@@@@@@
#                 @@@@@@@@@@
#                @@@@@@@@@@@@
#               @@@@@@@@@@@@@@
#              @@@@@@@@@@@@@@@@
#             @@@@@@@@@@@@@@@@@@
#            @@@@@@@@@@@@@@@@@@@@
#           @@@@@@@@@@@@@@@@@@@@@@
#          @@@@@@@@@@@@@@@@@@@@@@@@
#         @@@@@@@@@@@@@@@@@@@@@@@@@@
#        @@@@@@@@@@@@@@@@@@@@@@@@@@@@
#       @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
#      @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
#     @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
#    @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
#   @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# @@@@@@@@@@       @@@@@@@@@@       @@@@@@@@@@
# @@@@@@@@@@       @@@@@@@@@@       @@@@@@@@@@
# @@@@@@@@@@       @@@@@@@@@@       @@@@@@@@@@
# @@@@@@@@@@       @@@@@@@@@@       @@@@@@@@@@
# @@@@@@@@@@       @@@@@@@@@@       @@@@@@@@@@
# @@@@@@@@@@       @@@@@@@@@@       @@@@@@@@@@
# @@@@@@@@@@       @@@@@@@@@@       @@@@@@@@@@
# ...
