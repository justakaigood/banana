# %% [markdown]
# 可以自訂長度的米字條

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
print("輸入長度")
egg=input()
import random
for i in range (1,100):
    print("*"*random.randint(0,float(egg)))
# Out:
# 輸入長度
# 55
# **************************************
# **************
# *****************************
# ********************************
# **********************
# **************************************
# ****************
# *************************************************
# **
# ****
# ***************************************
# *****
# ******
# ********
# *****************************************
# ******************************************************
# **************
# ********************************************
# **************************************************
# ******************************
# ************************************************
# *************************************
# ******
# **********
# ****************************************************
# ***********
# *************************************
# *************************************
# *********************************
# ******************
# *
# ********
# *************************
# *****************
# ...
